# %% [markdown]
# # Подгрузка модулей, выбор фич

# %%
from utils.support import *

from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Concatenate, Dense, BatchNormalization,\
                                    Flatten, MaxPooling1D, Reshape, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import Callback, ModelCheckpoint

from sklearn.metrics import roc_curve, recall_score, make_scorer
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.model_selection import train_test_split
# Out:
# 2025-08-10 17:51:31.972662: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-10 17:51:31.977115: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-10 17:51:32.041270: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-08-10 17:51:32.041377: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-08-10 17:51:32.049274: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-10 17:51:32.086418: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-10 17:51:32.087762: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-10 17:51:32.956174: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = open_data('data/bank_data_final_2.csv')
data = data[[col for col in data.columns if data[col].dtype != 'object']]
data.head(2)
# Out:
#         fraud_bool  income  name_email_similarity  \
# 634102           0       7               0.546775
# 173005           0       8               0.715285
#
#         current_address_months_count  customer_age  days_since_request  \
# 634102                           375             3            0.027343
# 173005                           379             4            0.007504
#
#         intended_balcon_amount  zip_count_4w  velocity_6h  velocity_24h  ...  \
# 634102               -0.654816          1455  3871.735367   3169.891947  ...
# 173005               18.068853          1086  9501.114204   6294.918432  ...
#
#         zip_peak  bank_branch_count_8w  bank_branch_peak  \
# 634102         1                    14                 1
# 173005         1                   748                 0
#
#         zip_transaction_ratio  max_zip_sum  zip_sum_ratio        vel_1  \
# 634102             194.000000     291000.0          7.275 -2114.180477
# 173005               2.899866     217200.0          5.430  5708.831358
#
#               vel_2       vel_3     vel_4
# 634102 -1776.742716  107.040705 -0.011601
# 173005  1203.137209 -235.726930 -0.124511
#
# [2 rows x 79 columns]

# %%
X, y = data.drop('fraud_bool', axis=1), data['fraud_bool']

# %%
# функция, возвращающая recall для данного fpr
def get_recall(y_true, y_pred, target_fpr=0.05, is_probabilities_in=True):
    classes = np.unique(y_true)
    if len(classes) < 2:
        return 0.0

    try:
        fpr, tpr, thresholds = roc_curve(y_true, y_pred)
        if len(fpr) == 0:
            print('Empty FPR.')
            return 0.0

        idx = np.abs(fpr - target_fpr).argmin()
        thresh = thresholds[idx]
        if is_probabilities_in:
            y_pred = (y_pred >= thresh).astype('uint8')

        return recall_score(y_true, y_pred)
    except Exception:
        print('Exception!')
        return 0.0

recall_at_5_fpr = make_scorer(get_recall)

# %% [markdown]
# Итак, в классических моделях экспериментировали с фичами: какие брать, какие нет. Оказалось, что фичи с якобы линейными зависимостями с целевой переменной (напомним: бинарной fraud_bool с дисбалансом классов) в целом показывают себя лучше. Поэтому решил воспользоваться select_k_best:

# %%
kbest = SelectKBest(mutual_info_classif, k=32)
kbest.fit(X, y)
# Out:
# SelectKBest(k=32, score_func=<function mutual_info_classif at 0x7c00790fd750>)

# %%
best_k_features = list(kbest.get_feature_names_out())

# %%
best_k_features
# Out:
# ['income',
#  'customer_age',
#  'email_is_free',
#  'phone_home_valid',
#  'phone_mobile_valid',
#  'has_other_cards',
#  'proposed_credit_limit',
#  'source',
#  'keep_alive_session',
#  'device_distinct_emails_8w',
#  'only_one_valid',
#  'payment_type_AA',
#  'payment_type_AC',
#  'device_os_windows',
#  'device_os_linux',
#  'device_os_other',
#  'n_e_cat_similarity',
#  'danger_spike',
#  'cur_address_months_binned_first_spike',
#  'cur_address_months_binned_danger_spike',
#  'cur_address_fraud_zone',
#  'is_recent_request',
#  'bank_months_count_qt',
#  'bank_months_0_2',
#  'bank_months_strong_peak',
#  'cur_address_months_binned_end_spike',
#  'births_danger_zone',
#  'is_credit_limit_high',
#  'intended_balcon_peak_1',
#  'has_entered_website_recently',
#  'zip_peak',
#  'bank_branch_peak']

# %%
save_list(best_k_features, 'best_k_features')

# %%
best_k_features = open_list('logs/best_k_features.txt')

# %% [markdown]
# ---

# %%
# разделение данных на обучающую и валидационную выборки
X_train, X_val, y_train, y_val = train_test_split(X[best_k_features], y, test_size=0.25, random_state=rs, stratify=y)

# %% [markdown]
# Не будем использовать оверсемплинг - как показали эксперименты, он плохо работает с нашими данными. Но оставить ситуацию как есть, конечно, нельзя. В методе fit в Keras API можно указать веса классов. Вычислим их и будем использовать в дальнейшем:

# %%
from sklearn.utils import class_weight

def compute_class_weight(y_train):
    classes = np.unique(y_train)
    cw = class_weight.compute_class_weight('balanced', classes=classes, y=y_train)
    class_weight_dict = {classes[i]: float(cw[i]) for i in range(len(classes))}
    return class_weight_dict
class_weight_dict = compute_class_weight(y_train)
class_weight_dict
# Out:
# {0: 0.5055761680831787, 1: 45.33365570599613}

# %%
# кол-во входных нейронов
input_dims = 32

# %% [markdown]
# Ну, теперь к самим нейронкам.

# %% [markdown]
# # 6. Нейронные сети

# %% [markdown]
# Как по мне, моя задача не требует каких-то сложных нейронных сетей, но попытаться стоит. Тем более, оказалось, что вычисления проходят даже быстрее, чем с классическими моделями.

# %% [markdown]
# ## Dense Neural Network (DNN)

# %% [markdown]
# Начнем с обычной полносвязной сети:

# %%
# Простая 3-х слойная нейронная сеть с регулиризацией
model_dnn = Sequential(
    name = 'DNN_Model', 
    layers = [
        Dense(64, input_dim=input_dims, activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(0.2),
        Dense(input_dims, activation='relu'),
        BatchNormalization(),
        Dense(1, activation='sigmoid')
    ]
)

# %% [markdown]
# К сожалению, в связи со сложной архитектурой метода fit не получится передать обычную функцию get_recall (из models.ipynb) в качестве метрики. Нужно написать наследующий от Callback класс. Заодно напишем и функцию, которая проводит весь этап компиляции и обучения модели:

# %%
class RecallAtFPR(Callback):
    """
        Класс, вычисляющий целевую метрику при обучении Keras API модели.
        
        Аргументы класса:
        X_val, y_val: numpy arrays
        target_fpr: целевой FPR
        batch_size: batch_size для predict
        every_n_epochs: считать метрику каждые N эпох, чтобы экономить время
        """
    def __init__(self, X_val, y_val, fpr=0.05, batch_size=None, every_n_epochs=4):
        super().__init__()
        self.X_val = X_val
        self.y_val = y_val
        self.batch_size = batch_size
        self.target_fpr = fpr
        self.every_n_epochs= every_n_epochs
        
    def on_epoch_end(self, epoch, logs=None):
        if (epoch+1) % self.every_n_epochs != 0:
            return
        
        logs = logs or {}
        # делаем предсказание
        y_prob = self.model.predict(self.X_val, batch_size=self.batch_size, verbose=0)
        # взависимости от размера возвращенного predict получаем предсказания
        if y_prob.ndim == 1:
            pass
        elif y_prob.ndim == 2 and y_prob.shape[1] == 2:
            y_prob = y_prob[:, 1]
        else:
            y_prob = y_prob.ravel()
            
        # если значения не в диапозоне [0, 1] - значит, логиты; применяем softmax
        if y_prob.min() < 0 or y_prob.max() > 1:
            y_prob = 1/(1+np.exp(-y_prob))
        
        # считаем roc показатели и обрабатываем исключения
        try:
            fpr, tpr, thresholds = roc_curve(self.y_val, y_prob)
        except ValueError:
            logs['val_recall_at_fpr'] = 0.0
            print(f'\nEpoch {epoch+1}: no valid ROC (single-class in val)')
            return
        
        if fpr.size == 0:
            logs['val_recall_at_fpr'] = 0.0
            print(f"\nEpoch {epoch+1}: empty fpr.")
            return
        
        # находим показатель tpr при fpr=5%
        idx = np.argmin(np.abs(fpr-self.target_fpr))
        thresh = thresholds[idx]
        y_pred = (y_prob >= thresh).astype('uint8')
        score = recall_score(self.y_val, y_pred)
        
        logs['val_recall_at_fpr'] = score
        print(f"\nEpoch {epoch+1}: recall@5 = {score:.4f}")

# %%
def optimize_model(model, filepath_to_save, 
                   X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val, 
                   optimizer=None, loss='binary_crossentropy', metrics=['AUC', "Recall", "Precision"], 
                   fpr=0.05, batch_size=1024, epochs=20, every_n_epochs=4,
                   class_weight=class_weight_dict):
    """
    Функция, проводящая оптимизацию для заданной модели.
    
    
    model (Keras API model) - модель на вход, 
    filepath_to_save (str) - путь к файлу для сохранения лучшей версии модели,
    X_train (np.array) - обучающая выборка, 
    y_train (np.array) - обучающая целевая переменная,
    X_val(np.array) - валидационная выборка, 
    y_val (np.array) - валидационная целевая переменная,
    
    optimizer (tf.keras.optimizers) - функция-оптимизатор при компиляции модели, 
    loss (func типа tf.keras.losses) - функция потерь, 
    metrics (func типа tf.keras.metrics) - метрика,
    fpr (float, [0, 1]) - показатель fpr для нахождения tpr в данной точке на ROC-кривой,
    batch_size (int) - размер выборки,
    epochs=20 - количество эпох для обучения,
    every_n_epochs=4 - какие каждый n эпох производить рассчет метрики на валидации,
    class_weight - веса классов
    """
    
    if optimizer is None:
        optimizer=Adam(0.001)

    # компиляция модели
    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=metrics
    )

    # создаем объект класса отзыва
    recall_callback = RecallAtFPR(X_val, y_val, fpr, batch_size, every_n_epochs)
    # создаем чекпоинт модели
    checkpoint = ModelCheckpoint(
        filepath = filepath_to_save,
        monitor='val_recall_at_fpr',
        save_best_only=True,
        save_weight_only=False,
        mode='max',
        verbose=1
    )
    # обучение нейронки
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        class_weight=class_weight,
        callbacks=[recall_callback, checkpoint]
    )
    
    return history

# %% [markdown]
# Итак, оптимизируем DNN:

# %%
optimize_model(model_dnn, 'logs/keras/test.keras')
# Out:
# Epoch 1/20
# 549/550 [============================>.] - ETA: 0s - loss: 0.6411 - auc: 0.7190 - recall: 0.6552 - precision: 0.0212WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 4s 5ms/step - loss: 0.6411 - auc: 0.7189 - recall: 0.6551 - precision: 0.0212 - val_loss: 0.1384 - val_auc: 0.6207 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 2/20
# 548/550 [============================>.] - ETA: 0s - loss: 0.5506 - auc: 0.7979 - recall: 0.7205 - precision: 0.0285WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 6ms/step - loss: 0.5507 - auc: 0.7979 - recall: 0.7205 - precision: 0.0285 - val_loss: 0.8588 - val_auc: 0.7831 - val_recall: 0.8196 - val_precision: 0.0229
# Epoch 3/20
# 540/550 [============================>.] - ETA: 0s - loss: 0.5376 - auc: 0.8099 - recall: 0.7292 - precision: 0.0299WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 6ms/step - loss: 0.5373 - auc: 0.8097 - recall: 0.7284 - precision: 0.0298 - val_loss: 0.3166 - val_auc: 0.8354 - val_recall: 0.5687 - val_precision: 0.0542
# Epoch 4/20
# 549/550 [============================>.] - ETA: 0s - loss: 0.5302 - auc: 0.8170 - recall: 0.7319 - precision: 0.0312
# Epoch 4: recall@5 = 0.3612
#
# Epoch 4: val_recall_at_fpr improved from -inf to 0.36122, saving model to data/keras/test.keras
# 550/550 [==============================] - 4s 6ms/step - loss: 0.5302 - auc: 0.8170 - recall: 0.7319 - precision: 0.0312 - val_loss: 0.3932 - val_auc: 0.8264 - val_recall: 0.6238 - val_precision: 0.0421 - val_recall_at_fpr: 0.3612
# Epoch 5/20
# 543/550 [============================>.] - ETA: 0s - loss: 0.5298 - auc: 0.8160 - recall: 0.7238 - precision: 0.0307WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 5ms/step - loss: 0.5299 - auc: 0.8157 - recall: 0.7237 - precision: 0.0307 - val_loss: 0.5879 - val_auc: 0.8360 - val_recall: 0.8221 - val_precision: 0.0281
# Epoch 6/20
# 545/550 [============================>.] - ETA: 0s - loss: 0.5264 - auc: 0.8198 - recall: 0.7343 - precision: 0.0318WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 5ms/step - loss: 0.5262 - auc: 0.8200 - recall: 0.7345 - precision: 0.0318 - val_loss: 0.2551 - val_auc: 0.7082 - val_recall: 0.2340 - val_precision: 0.0436
# Epoch 7/20
# 548/550 [============================>.] - ETA: 0s - loss: 0.5267 - auc: 0.8193 - recall: 0.7263 - precision: 0.0316WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 5ms/step - loss: 0.5267 - auc: 0.8194 - recall: 0.7263 - precision: 0.0316 - val_loss: 0.4636 - val_auc: 0.8334 - val_recall: 0.7205 - val_precision: 0.0356
# Epoch 8/20
# 544/550 [============================>.] - ETA: 0s - loss: 0.5213 - auc: 0.8236 - recall: 0.7385 - precision: 0.0322
# Epoch 8: recall@5 = 0.3960
#
# Epoch 8: val_recall_at_fpr improved from 0.36122 to 0.39603, saving model to data/keras/test.keras
# 550/550 [==============================] - 3s 6ms/step - loss: 0.5211 - auc: 0.8237 - recall: 0.7382 - precision: 0.0322 - val_loss: 0.4858 - val_auc: 0.8317 - val_recall: 0.7345 - val_precision: 0.0344 - val_recall_at_fpr: 0.3960
# Epoch 9/20
# 548/550 [============================>.] - ETA: 0s - loss: 0.5219 - auc: 0.8234 - recall: 0.7313 - precision: 0.0322WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 6ms/step - loss: 0.5218 - auc: 0.8235 - recall: 0.7318 - precision: 0.0322 - val_loss: 0.4859 - val_auc: 0.8227 - val_recall: 0.7224 - val_precision: 0.0320
# Epoch 10/20
# 544/550 [============================>.] - ETA: 0s - loss: 0.5267 - auc: 0.8193 - recall: 0.7300 - precision: 0.0316WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 5ms/step - loss: 0.5262 - auc: 0.8197 - recall: 0.7305 - precision: 0.0316 - val_loss: 0.6017 - val_auc: 0.8220 - val_recall: 0.7887 - val_precision: 0.0282
# Epoch 11/20
# 542/550 [============================>.] - ETA: 0s - loss: 0.5243 - auc: 0.8223 - recall: 0.7390 - precision: 0.0322WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 5ms/step - loss: 0.5236 - auc: 0.8223 - recall: 0.7392 - precision: 0.0321 - val_loss: 0.4569 - val_auc: 0.8374 - val_recall: 0.7220 - val_precision: 0.0360
# Epoch 12/20
# 543/550 [============================>.] - ETA: 0s - loss: 0.5227 - auc: 0.8219 - recall: 0.7308 - precision: 0.0318
# Epoch 12: recall@5 = 0.3569
#
# Epoch 12: val_recall_at_fpr did not improve from 0.39603
# 550/550 [==============================] - 3s 6ms/step - loss: 0.5235 - auc: 0.8220 - recall: 0.7311 - precision: 0.0319 - val_loss: 0.6183 - val_auc: 0.8263 - val_recall: 0.8245 - val_precision: 0.0268 - val_recall_at_fpr: 0.3569
# Epoch 13/20
# 543/550 [============================>.] - ETA: 0s - loss: 0.5210 - auc: 0.8238 - recall: 0.7384 - precision: 0.0319WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 5ms/step - loss: 0.5210 - auc: 0.8239 - recall: 0.7381 - precision: 0.0320 - val_loss: 0.4658 - val_auc: 0.8360 - val_recall: 0.7297 - val_precision: 0.0354
# Epoch 14/20
# 543/550 [============================>.] - ETA: 0s - loss: 0.5253 - auc: 0.8207 - recall: 0.7283 - precision: 0.0321WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 5ms/step - loss: 0.5259 - auc: 0.8201 - recall: 0.7268 - precision: 0.0320 - val_loss: 0.7382 - val_auc: 0.8043 - val_recall: 0.8293 - val_precision: 0.0240
# Epoch 15/20
# 541/550 [============================>.] - ETA: 0s - loss: 0.5275 - auc: 0.8192 - recall: 0.7337 - precision: 0.0314WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 6ms/step - loss: 0.5267 - auc: 0.8194 - recall: 0.7339 - precision: 0.0314 - val_loss: 0.6924 - val_auc: 0.8104 - val_recall: 0.8419 - val_precision: 0.0239
# Epoch 16/20
# 546/550 [============================>.] - ETA: 0s - loss: 0.5211 - auc: 0.8236 - recall: 0.7369 - precision: 0.0313
# Epoch 16: recall@5 = 0.3090
#
# Epoch 16: val_recall_at_fpr did not improve from 0.39603
# 550/550 [==============================] - 4s 6ms/step - loss: 0.5212 - auc: 0.8233 - recall: 0.7361 - precision: 0.0312 - val_loss: 0.6685 - val_auc: 0.8057 - val_recall: 0.7916 - val_precision: 0.0259 - val_recall_at_fpr: 0.3090
# Epoch 17/20
# 547/550 [============================>.] - ETA: 0s - loss: 0.5200 - auc: 0.8247 - recall: 0.7348 - precision: 0.0320WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 5ms/step - loss: 0.5203 - auc: 0.8247 - recall: 0.7347 - precision: 0.0320 - val_loss: 0.4466 - val_auc: 0.8386 - val_recall: 0.7268 - val_precision: 0.0359
# Epoch 18/20
# 543/550 [============================>.] - ETA: 0s - loss: 0.5203 - auc: 0.8250 - recall: 0.7402 - precision: 0.0319WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 5ms/step - loss: 0.5196 - auc: 0.8252 - recall: 0.7407 - precision: 0.0319 - val_loss: 0.5964 - val_auc: 0.8206 - val_recall: 0.7843 - val_precision: 0.0290
# Epoch 19/20
# 542/550 [============================>.] - ETA: 0s - loss: 0.5205 - auc: 0.8243 - recall: 0.7326 - precision: 0.0318WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 3s 5ms/step - loss: 0.5207 - auc: 0.8245 - recall: 0.7328 - precision: 0.0319 - val_loss: 0.4572 - val_auc: 0.8359 - val_recall: 0.7244 - val_precision: 0.0359
# Epoch 20/20
# 548/550 [============================>.] - ETA: 0s - loss: 0.5196 - auc: 0.8252 - recall: 0.7380 - precision: 0.0317
# Epoch 20: recall@5 = 0.3288
#
# Epoch 20: val_recall_at_fpr did not improve from 0.39603
# 550/550 [==============================] - 4s 7ms/step - loss: 0.5197 - auc: 0.8251 - recall: 0.7381 - precision: 0.0318 - val_loss: 0.5801 - val_auc: 0.8226 - val_recall: 0.7698 - val_precision: 0.0304 - val_recall_at_fpr: 0.3288

# %%
y_pred = model_dnn.predict(X_val)
y_pred
# Out:
# 5860/5860 [==============================] - 8s 1ms/step
# array([[0.6275351 ],
#        [0.29558596],
#        [0.1217978 ],
#        ...,
#        [0.07900803],
#        [0.07967044],
#        [0.2555716 ]], dtype=float32)

# %%
get_recall(y_val, y_pred)
# Out:
# 0.38636363636363635

# %% [markdown]
# Получили показатель 38%, что пока что проигрывает лучшей модели - Catboost. Попробуем добавить больше слоев:

# %% [markdown]
# ## Deep Block Neural Network

# %%
model_deep_block = Sequential(
    name='Deep_Block',
    layers=[
        Dense(256, input_dim = input_dims, activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(0.3),
        
        Dense(128, activation='relu', kernel_regularizer=l2(0.0001)),
        BatchNormalization(),
        Dropout(0.3),
        
        Dense(64, activation='relu', kernel_regularizer=l2(0.0001)),
        BatchNormalization(),
        Dropout(0.2),
        
        Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(0.15),
        
        Dense(1, activation='sigmoid')
    ]
)

optimize_model(model_deep_block, 'logs/keras/model_deep_block_1.keras')
# Out:
# Epoch 1/20
# 547/550 [============================>.] - ETA: 0s - loss: 0.7607 - auc: 0.6460 - recall: 0.5926 - precision: 0.0170WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 9s 14ms/step - loss: 0.7601 - auc: 0.6467 - recall: 0.5938 - precision: 0.0171 - val_loss: 0.2313 - val_auc: 0.7028 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 2/20
# 547/550 [============================>.] - ETA: 0s - loss: 0.6657 - auc: 0.7353 - recall: 0.6840 - precision: 0.0222WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 13ms/step - loss: 0.6656 - auc: 0.7356 - recall: 0.6841 - precision: 0.0222 - val_loss: 0.6015 - val_auc: 0.7995 - val_recall: 0.6634 - val_precision: 0.0289
# Epoch 3/20
# 546/550 [============================>.] - ETA: 0s - loss: 0.6232 - auc: 0.7697 - recall: 0.6896 - precision: 0.0251WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 13ms/step - loss: 0.6237 - auc: 0.7693 - recall: 0.6887 - precision: 0.0251 - val_loss: 0.7902 - val_auc: 0.7642 - val_recall: 0.7374 - val_precision: 0.0232
# Epoch 4/20
# 546/550 [============================>.] - ETA: 0s - loss: 0.6021 - auc: 0.7837 - recall: 0.7127 - precision: 0.0262
# Epoch 4: recall@5 = 0.3133
#
# Epoch 4: val_recall_at_fpr improved from -inf to 0.31335, saving model to logs/keras/model_deep_block_1.keras
# 550/550 [==============================] - 10s 18ms/step - loss: 0.6022 - auc: 0.7838 - recall: 0.7124 - precision: 0.0262 - val_loss: 0.6218 - val_auc: 0.7987 - val_recall: 0.7229 - val_precision: 0.0269 - val_recall_at_fpr: 0.3133
# Epoch 5/20
# 550/550 [==============================] - ETA: 0s - loss: 0.5832 - auc: 0.7955 - recall: 0.7386 - precision: 0.0267WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 13ms/step - loss: 0.5832 - auc: 0.7955 - recall: 0.7386 - precision: 0.0267 - val_loss: 0.3089 - val_auc: 0.8162 - val_recall: 0.4720 - val_precision: 0.0607
# Epoch 6/20
# 549/550 [============================>.] - ETA: 0s - loss: 0.5700 - auc: 0.8035 - recall: 0.7460 - precision: 0.0274WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 13ms/step - loss: 0.5701 - auc: 0.8035 - recall: 0.7460 - precision: 0.0274 - val_loss: 0.3898 - val_auc: 0.8331 - val_recall: 0.5986 - val_precision: 0.0475
# Epoch 7/20
# 549/550 [============================>.] - ETA: 0s - loss: 0.5779 - auc: 0.7919 - recall: 0.7246 - precision: 0.0265WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 13ms/step - loss: 0.5778 - auc: 0.7919 - recall: 0.7247 - precision: 0.0265 - val_loss: 0.4454 - val_auc: 0.8248 - val_recall: 0.6838 - val_precision: 0.0376
# Epoch 8/20
# 547/550 [============================>.] - ETA: 0s - loss: 0.5633 - auc: 0.8025 - recall: 0.7398 - precision: 0.0276
# Epoch 8: recall@5 = 0.3748
#
# Epoch 8: val_recall_at_fpr improved from 0.31335 to 0.37476, saving model to logs/keras/model_deep_block_1.keras
# 550/550 [==============================] - 10s 19ms/step - loss: 0.5630 - auc: 0.8027 - recall: 0.7398 - precision: 0.0276 - val_loss: 0.4737 - val_auc: 0.8349 - val_recall: 0.7249 - val_precision: 0.0358 - val_recall_at_fpr: 0.3748
# Epoch 9/20
# 547/550 [============================>.] - ETA: 0s - loss: 0.5553 - auc: 0.8057 - recall: 0.7392 - precision: 0.0283WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 8s 14ms/step - loss: 0.5556 - auc: 0.8056 - recall: 0.7390 - precision: 0.0283 - val_loss: 0.4586 - val_auc: 0.8356 - val_recall: 0.6920 - val_precision: 0.0383
# Epoch 10/20
# 548/550 [============================>.] - ETA: 0s - loss: 0.5521 - auc: 0.8080 - recall: 0.7319 - precision: 0.0292WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 13ms/step - loss: 0.5520 - auc: 0.8081 - recall: 0.7321 - precision: 0.0292 - val_loss: 0.3806 - val_auc: 0.8349 - val_recall: 0.6306 - val_precision: 0.0447
# Epoch 11/20
# 550/550 [==============================] - ETA: 0s - loss: 0.5515 - auc: 0.8065 - recall: 0.7278 - precision: 0.0289WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 14ms/step - loss: 0.5515 - auc: 0.8065 - recall: 0.7278 - precision: 0.0289 - val_loss: 0.3932 - val_auc: 0.8337 - val_recall: 0.6659 - val_precision: 0.0411
# Epoch 12/20
# 547/550 [============================>.] - ETA: 0s - loss: 0.5467 - auc: 0.8085 - recall: 0.7234 - precision: 0.0293
# Epoch 12: recall@5 = 0.3825
#
# Epoch 12: val_recall_at_fpr improved from 0.37476 to 0.38250, saving model to logs/keras/model_deep_block_1.keras
# 550/550 [==============================] - 10s 17ms/step - loss: 0.5476 - auc: 0.8083 - recall: 0.7232 - precision: 0.0294 - val_loss: 0.5195 - val_auc: 0.8290 - val_recall: 0.7872 - val_precision: 0.0293 - val_recall_at_fpr: 0.3825
# Epoch 13/20
# 550/550 [==============================] - ETA: 0s - loss: 0.5502 - auc: 0.8058 - recall: 0.7265 - precision: 0.0288WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 8s 14ms/step - loss: 0.5502 - auc: 0.8058 - recall: 0.7265 - precision: 0.0288 - val_loss: 0.5056 - val_auc: 0.8038 - val_recall: 0.7389 - val_precision: 0.0302
# Epoch 14/20
# 549/550 [============================>.] - ETA: 0s - loss: 0.5535 - auc: 0.8021 - recall: 0.7352 - precision: 0.0276WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 13ms/step - loss: 0.5537 - auc: 0.8020 - recall: 0.7352 - precision: 0.0276 - val_loss: 0.6021 - val_auc: 0.8342 - val_recall: 0.8772 - val_precision: 0.0236
# Epoch 15/20
# 547/550 [============================>.] - ETA: 0s - loss: 0.5486 - auc: 0.8067 - recall: 0.7291 - precision: 0.0286WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 8s 14ms/step - loss: 0.5485 - auc: 0.8067 - recall: 0.7287 - precision: 0.0286 - val_loss: 0.6351 - val_auc: 0.8203 - val_recall: 0.8143 - val_precision: 0.0271
# Epoch 16/20
# 546/550 [============================>.] - ETA: 0s - loss: 0.5412 - auc: 0.8133 - recall: 0.7455 - precision: 0.0297
# Epoch 16: recall@5 = 0.4033
#
# Epoch 16: val_recall_at_fpr improved from 0.38250 to 0.40329, saving model to logs/keras/model_deep_block_1.keras
# 550/550 [==============================] - 10s 18ms/step - loss: 0.5418 - auc: 0.8130 - recall: 0.7452 - precision: 0.0297 - val_loss: 0.3823 - val_auc: 0.8385 - val_recall: 0.6649 - val_precision: 0.0423 - val_recall_at_fpr: 0.4033
# Epoch 17/20
# 546/550 [============================>.] - ETA: 0s - loss: 0.5393 - auc: 0.8146 - recall: 0.7451 - precision: 0.0295WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 8s 14ms/step - loss: 0.5399 - auc: 0.8144 - recall: 0.7448 - precision: 0.0296 - val_loss: 0.3127 - val_auc: 0.8040 - val_recall: 0.4217 - val_precision: 0.0497
# Epoch 18/20
# 550/550 [==============================] - ETA: 0s - loss: 0.5496 - auc: 0.8039 - recall: 0.7195 - precision: 0.0281WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 8s 14ms/step - loss: 0.5496 - auc: 0.8039 - recall: 0.7195 - precision: 0.0281 - val_loss: 0.7469 - val_auc: 0.7968 - val_recall: 0.9076 - val_precision: 0.0186
# Epoch 19/20
# 549/550 [============================>.] - ETA: 0s - loss: 0.5480 - auc: 0.8064 - recall: 0.7381 - precision: 0.0281WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 8s 14ms/step - loss: 0.5482 - auc: 0.8063 - recall: 0.7379 - precision: 0.0281 - val_loss: 0.2696 - val_auc: 0.7881 - val_recall: 0.2616 - val_precision: 0.0543
# Epoch 20/20
# 547/550 [============================>.] - ETA: 0s - loss: 0.5496 - auc: 0.8047 - recall: 0.7331 - precision: 0.0287
# Epoch 20: recall@5 = 0.3946
#
# Epoch 20: val_recall_at_fpr did not improve from 0.40329
# 550/550 [==============================] - 8s 15ms/step - loss: 0.5496 - auc: 0.8047 - recall: 0.7331 - precision: 0.0287 - val_loss: 0.7313 - val_auc: 0.8341 - val_recall: 0.9594 - val_precision: 0.0170 - val_recall_at_fpr: 0.3946

# %% [markdown]
# Уже лучше! 41%. Попробуем "пирамидальную" структуру:

# %%
model_deep_block_pyramide = Sequential(
    name='Deep_Block_Pyramid',
    layers=[
        Dense(64, input_dim = input_dims, activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(0.3),
        
        Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(0.4),
        
        Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(0.3),
        
        Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(0.15),
        
        Dense(1, activation='sigmoid')
    ]
)

optimize_model(model_deep_block_pyramide, 'logs/keras/model_deep_block_pyramid.keras', 
               every_n_epochs=3, epochs=30)
# Out:
# Epoch 1/30
# 548/550 [============================>.] - ETA: 0s - loss: 0.8472 - auc: 0.6628 - recall: 0.6070 - precision: 0.0179WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 9s 14ms/step - loss: 0.8466 - auc: 0.6631 - recall: 0.6074 - precision: 0.0179 - val_loss: 0.5724 - val_auc: 0.7779 - val_recall: 0.5837 - val_precision: 0.0299
# Epoch 2/30
# 546/550 [============================>.] - ETA: 0s - loss: 0.7433 - auc: 0.7286 - recall: 0.6600 - precision: 0.0221WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 10ms/step - loss: 0.7431 - auc: 0.7289 - recall: 0.6601 - precision: 0.0221 - val_loss: 0.4643 - val_auc: 0.7479 - val_recall: 0.4304 - val_precision: 0.0280
# Epoch 3/30
# 547/550 [============================>.] - ETA: 0s - loss: 0.6848 - auc: 0.7587 - recall: 0.6654 - precision: 0.0253
# Epoch 3: recall@5 = 0.3897
#
# Epoch 3: val_recall_at_fpr improved from -inf to 0.38975, saving model to logs/keras/model_deep_block_pyramid.keras
# 550/550 [==============================] - 7s 13ms/step - loss: 0.6847 - auc: 0.7590 - recall: 0.6655 - precision: 0.0253 - val_loss: 0.4957 - val_auc: 0.8302 - val_recall: 0.5682 - val_precision: 0.0496 - val_recall_at_fpr: 0.3897
# Epoch 4/30
# 545/550 [============================>.] - ETA: 0s - loss: 0.6491 - auc: 0.7661 - recall: 0.6581 - precision: 0.0260WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 11ms/step - loss: 0.6489 - auc: 0.7661 - recall: 0.6581 - precision: 0.0261 - val_loss: 0.3384 - val_auc: 0.7800 - val_recall: 0.1547 - val_precision: 0.0769
# Epoch 5/30
# 550/550 [==============================] - ETA: 0s - loss: 0.6217 - auc: 0.7703 - recall: 0.6460 - precision: 0.0263WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 11ms/step - loss: 0.6217 - auc: 0.7703 - recall: 0.6460 - precision: 0.0263 - val_loss: 0.3877 - val_auc: 0.8344 - val_recall: 0.4676 - val_precision: 0.0683
# Epoch 6/30
# 545/550 [============================>.] - ETA: 0s - loss: 0.6138 - auc: 0.7544 - recall: 0.6559 - precision: 0.0225
# Epoch 6: recall@5 = 0.3767
#
# Epoch 6: val_recall_at_fpr did not improve from 0.38975
# 550/550 [==============================] - 7s 13ms/step - loss: 0.6139 - auc: 0.7543 - recall: 0.6546 - precision: 0.0225 - val_loss: 0.5210 - val_auc: 0.8288 - val_recall: 0.6354 - val_precision: 0.0414 - val_recall_at_fpr: 0.3767
# Epoch 7/30
# 544/550 [============================>.] - ETA: 0s - loss: 0.5880 - auc: 0.7643 - recall: 0.6440 - precision: 0.0238WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 10ms/step - loss: 0.5888 - auc: 0.7638 - recall: 0.6444 - precision: 0.0238 - val_loss: 0.3918 - val_auc: 0.8288 - val_recall: 0.6712 - val_precision: 0.0395
# Epoch 8/30
# 547/550 [============================>.] - ETA: 0s - loss: 0.5854 - auc: 0.7609 - recall: 0.6554 - precision: 0.0228WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 11ms/step - loss: 0.5848 - auc: 0.7611 - recall: 0.6560 - precision: 0.0228 - val_loss: 0.4558 - val_auc: 0.8366 - val_recall: 0.7384 - val_precision: 0.0348
# Epoch 9/30
# 549/550 [============================>.] - ETA: 0s - loss: 0.5783 - auc: 0.7638 - recall: 0.6555 - precision: 0.0234
# Epoch 9: recall@5 = 0.3985
#
# Epoch 9: val_recall_at_fpr improved from 0.38975 to 0.39845, saving model to logs/keras/model_deep_block_pyramid.keras
# 550/550 [==============================] - 6s 11ms/step - loss: 0.5782 - auc: 0.7639 - recall: 0.6557 - precision: 0.0234 - val_loss: 0.5414 - val_auc: 0.8349 - val_recall: 0.8404 - val_precision: 0.0263 - val_recall_at_fpr: 0.3985
# Epoch 10/30
# 546/550 [============================>.] - ETA: 0s - loss: 0.5751 - auc: 0.7657 - recall: 0.6687 - precision: 0.0229WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 12ms/step - loss: 0.5752 - auc: 0.7655 - recall: 0.6694 - precision: 0.0229 - val_loss: 0.3117 - val_auc: 0.7458 - val_recall: 0.3883 - val_precision: 0.0379
# Epoch 11/30
# 546/550 [============================>.] - ETA: 0s - loss: 0.5715 - auc: 0.7675 - recall: 0.6395 - precision: 0.0245WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 13ms/step - loss: 0.5717 - auc: 0.7673 - recall: 0.6383 - precision: 0.0245 - val_loss: 0.6216 - val_auc: 0.8161 - val_recall: 0.7466 - val_precision: 0.0298
# Epoch 12/30
# 547/550 [============================>.] - ETA: 0s - loss: 0.5753 - auc: 0.7631 - recall: 0.6745 - precision: 0.0224
# Epoch 12: recall@5 = 0.3912
#
# Epoch 12: val_recall_at_fpr did not improve from 0.39845
# 550/550 [==============================] - 13s 24ms/step - loss: 0.5752 - auc: 0.7631 - recall: 0.6749 - precision: 0.0224 - val_loss: 0.4269 - val_auc: 0.8347 - val_recall: 0.7331 - val_precision: 0.0350 - val_recall_at_fpr: 0.3912
# Epoch 13/30
# 546/550 [============================>.] - ETA: 0s - loss: 0.5730 - auc: 0.7654 - recall: 0.6741 - precision: 0.0226WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 13ms/step - loss: 0.5729 - auc: 0.7653 - recall: 0.6749 - precision: 0.0225 - val_loss: 0.5451 - val_auc: 0.8323 - val_recall: 0.8395 - val_precision: 0.0260
# Epoch 14/30
# 547/550 [============================>.] - ETA: 0s - loss: 0.5743 - auc: 0.7657 - recall: 0.6893 - precision: 0.0221WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 13ms/step - loss: 0.5740 - auc: 0.7658 - recall: 0.6884 - precision: 0.0222 - val_loss: 0.5939 - val_auc: 0.8265 - val_recall: 0.7510 - val_precision: 0.0315
# Epoch 15/30
# 548/550 [============================>.] - ETA: 0s - loss: 0.5749 - auc: 0.7656 - recall: 0.6548 - precision: 0.0234
# Epoch 15: recall@5 = 0.3946
#
# Epoch 15: val_recall_at_fpr did not improve from 0.39845
# 550/550 [==============================] - 8s 14ms/step - loss: 0.5746 - auc: 0.7656 - recall: 0.6547 - precision: 0.0234 - val_loss: 0.4948 - val_auc: 0.8336 - val_recall: 0.6896 - val_precision: 0.0375 - val_recall_at_fpr: 0.3946
# Epoch 16/30
# 548/550 [============================>.] - ETA: 0s - loss: 0.5727 - auc: 0.7683 - recall: 0.6714 - precision: 0.0233WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 12ms/step - loss: 0.5730 - auc: 0.7680 - recall: 0.6712 - precision: 0.0232 - val_loss: 0.4044 - val_auc: 0.8382 - val_recall: 0.7321 - val_precision: 0.0361
# Epoch 17/30
# 549/550 [============================>.] - ETA: 0s - loss: 0.5717 - auc: 0.7739 - recall: 0.6709 - precision: 0.0246WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 8s 15ms/step - loss: 0.5717 - auc: 0.7739 - recall: 0.6710 - precision: 0.0246 - val_loss: 0.6648 - val_auc: 0.8136 - val_recall: 0.8211 - val_precision: 0.0252
# Epoch 18/30
# 548/550 [============================>.] - ETA: 0s - loss: 0.5772 - auc: 0.7629 - recall: 0.6889 - precision: 0.0219
# Epoch 18: recall@5 = 0.3854
#
# Epoch 18: val_recall_at_fpr did not improve from 0.39845
# 550/550 [==============================] - 8s 14ms/step - loss: 0.5773 - auc: 0.7628 - recall: 0.6887 - precision: 0.0219 - val_loss: 0.5119 - val_auc: 0.8316 - val_recall: 0.7394 - val_precision: 0.0334 - val_recall_at_fpr: 0.3854
# Epoch 19/30
# 545/550 [============================>.] - ETA: 0s - loss: 0.5690 - auc: 0.7762 - recall: 0.6682 - precision: 0.0252WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 11ms/step - loss: 0.5684 - auc: 0.7766 - recall: 0.6684 - precision: 0.0252 - val_loss: 0.5584 - val_auc: 0.8263 - val_recall: 0.7631 - val_precision: 0.0296
# Epoch 20/30
# 545/550 [============================>.] - ETA: 0s - loss: 0.5719 - auc: 0.7742 - recall: 0.6698 - precision: 0.0252WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 11ms/step - loss: 0.5733 - auc: 0.7740 - recall: 0.6696 - precision: 0.0253 - val_loss: 0.4148 - val_auc: 0.8370 - val_recall: 0.6489 - val_precision: 0.0434
# Epoch 21/30
# 549/550 [============================>.] - ETA: 0s - loss: 0.5723 - auc: 0.7717 - recall: 0.6904 - precision: 0.0231
# Epoch 21: recall@5 = 0.4057
#
# Epoch 21: val_recall_at_fpr improved from 0.39845 to 0.40571, saving model to logs/keras/model_deep_block_pyramid.keras
# 550/550 [==============================] - 7s 12ms/step - loss: 0.5723 - auc: 0.7717 - recall: 0.6905 - precision: 0.0231 - val_loss: 0.5039 - val_auc: 0.8368 - val_recall: 0.7814 - val_precision: 0.0312 - val_recall_at_fpr: 0.4057
# Epoch 22/30
# 546/550 [============================>.] - ETA: 0s - loss: 0.5730 - auc: 0.7680 - recall: 0.7080 - precision: 0.0219WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 7s 13ms/step - loss: 0.5735 - auc: 0.7676 - recall: 0.7071 - precision: 0.0218 - val_loss: 0.5072 - val_auc: 0.8363 - val_recall: 0.7766 - val_precision: 0.0312
# Epoch 23/30
# 547/550 [============================>.] - ETA: 0s - loss: 0.5700 - auc: 0.7722 - recall: 0.6660 - precision: 0.0237WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 11ms/step - loss: 0.5705 - auc: 0.7721 - recall: 0.6663 - precision: 0.0238 - val_loss: 0.5021 - val_auc: 0.8373 - val_recall: 0.7413 - val_precision: 0.0348
# Epoch 24/30
# 545/550 [============================>.] - ETA: 0s - loss: 0.5692 - auc: 0.7779 - recall: 0.6705 - precision: 0.0256
# Epoch 24: recall@5 = 0.4057
#
# Epoch 24: val_recall_at_fpr did not improve from 0.40571
# 550/550 [==============================] - 6s 12ms/step - loss: 0.5691 - auc: 0.7780 - recall: 0.6705 - precision: 0.0256 - val_loss: 0.4270 - val_auc: 0.8366 - val_recall: 0.6204 - val_precision: 0.0459 - val_recall_at_fpr: 0.4057
# Epoch 25/30
# 547/550 [============================>.] - ETA: 0s - loss: 0.5690 - auc: 0.7817 - recall: 0.6724 - precision: 0.0265WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 11ms/step - loss: 0.5690 - auc: 0.7819 - recall: 0.6728 - precision: 0.0265 - val_loss: 0.4606 - val_auc: 0.8375 - val_recall: 0.7157 - val_precision: 0.0369
# Epoch 26/30
# 544/550 [============================>.] - ETA: 0s - loss: 0.5603 - auc: 0.7944 - recall: 0.7260 - precision: 0.0266WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 11ms/step - loss: 0.5597 - auc: 0.7946 - recall: 0.7260 - precision: 0.0266 - val_loss: 0.4303 - val_auc: 0.8245 - val_recall: 0.6257 - val_precision: 0.0401
# Epoch 27/30
# 548/550 [============================>.] - ETA: 0s - loss: 0.5640 - auc: 0.7910 - recall: 0.6795 - precision: 0.0283
# Epoch 27: recall@5 = 0.2708
#
# Epoch 27: val_recall_at_fpr did not improve from 0.40571
# 550/550 [==============================] - 8s 14ms/step - loss: 0.5639 - auc: 0.7909 - recall: 0.6792 - precision: 0.0283 - val_loss: 0.8322 - val_auc: 0.7713 - val_recall: 0.8670 - val_precision: 0.0210 - val_recall_at_fpr: 0.2708
# Epoch 28/30
# 546/550 [============================>.] - ETA: 0s - loss: 0.5608 - auc: 0.7954 - recall: 0.7123 - precision: 0.0272WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 11ms/step - loss: 0.5602 - auc: 0.7955 - recall: 0.7126 - precision: 0.0271 - val_loss: 0.5924 - val_auc: 0.8279 - val_recall: 0.8308 - val_precision: 0.0267
# Epoch 29/30
# 549/550 [============================>.] - ETA: 0s - loss: 0.5568 - auc: 0.7996 - recall: 0.7182 - precision: 0.0278WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 10ms/step - loss: 0.5569 - auc: 0.7996 - recall: 0.7181 - precision: 0.0278 - val_loss: 0.7788 - val_auc: 0.7915 - val_recall: 0.7858 - val_precision: 0.0249
# Epoch 30/30
# 546/550 [============================>.] - ETA: 0s - loss: 0.5581 - auc: 0.7996 - recall: 0.7182 - precision: 0.0280
# Epoch 30: recall@5 = 0.3994
#
# Epoch 30: val_recall_at_fpr did not improve from 0.40571
# 550/550 [==============================] - 7s 12ms/step - loss: 0.5580 - auc: 0.7995 - recall: 0.7184 - precision: 0.0280 - val_loss: 0.3675 - val_auc: 0.8366 - val_recall: 0.6625 - val_precision: 0.0422 - val_recall_at_fpr: 0.3994

# %% [markdown]
# ## Wide & Deep Neural Network

# %% [markdown]
# Финальная архитектура - Wide & Deep (с объединением признаков). Состоит из линейной части и нелинейной. Другими словами: можем использовать вместе те самые признаки, которые мы разделили по информативности для разных типов моделей!

# %%
cat_features = open_list('logs/top_cat_features_list.txt')
len(cat_features)
# Out:
# 17

# %%
lin_features = open_list('logs/top_linear_features.txt')
tree_features = open_list('logs/top_non_linear_features.txt')

informative_features = list(set(tree_features + lin_features))
len(informative_features)
# Out:
# 42

# %%
linear_features = [feature for feature in informative_features if feature not in cat_features]
len(linear_features)
# Out:
# 25

# %%
wide_input_dims=17
deep_input_dims=25

# %%
X_train_cat, X_val_cat, X_train_lin, X_val_lin, y_train_cat, y_val_cat = train_test_split(
                X[cat_features], X[linear_features], y, test_size=0.25, random_state=rs, stratify=y)

# %%
# вычисляем новые веса классов (в прочем, они останутся такими же в силу параметра stratify)
class_weight_dict = compute_class_weight(y_train)
class_weight_dict
# Out:
# {0: 0.5055761680831787, 1: 45.33365570599613}

# %% [markdown]
# Строим сеть и обучаем:

# %%
# входной слой
deep_inp = Input(shape=(deep_input_dims,))
wide_inp = Input(shape=(wide_input_dims,))

# wide (линейная) часть
wide = Dense(1, activation='linear')(wide_inp)

# deep (глубокая) часть
deep = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(deep_inp)
deep = BatchNormalization()(deep)
deep = Dropout(0.1)(deep)

deep = Dense(64, activation='relu', kernel_regularizer=l2(0.0007))(deep)
deep = BatchNormalization()(deep)
deep = Dropout(0.15)(deep)

deep = Dense(32, activation='relu', kernel_regularizer=l2(0.001))(deep)
deep = BatchNormalization()(deep)
deep = Dropout(0.1)(deep)

# объединение слоев и построение модели
concat = Concatenate()([wide, deep])
out = Dense(1, activation='sigmoid')(concat)

model_wide_deep = Model(inputs=[wide_inp, deep_inp], outputs=out)

# оптимизация модели
optimize_model(model_wide_deep, 'logs/keras/model_wide_deep.keras', X_train=[X_train_cat, X_train_lin], 
               y_train=y_train, 
               X_val=[X_val_cat, X_val_lin], y_val=y_val, every_n_epochs=3, epochs=21)
# Out:
# Epoch 1/21
# 548/550 [============================>.] - ETA: 0s - loss: 0.7876 - auc: 0.6092 - recall: 0.5347 - precision: 0.0158WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 6s 8ms/step - loss: 0.7875 - auc: 0.6093 - recall: 0.5350 - precision: 0.0158 - val_loss: 0.7651 - val_auc: 0.6271 - val_recall: 0.4550 - val_precision: 0.0189
# Epoch 2/21
# 549/550 [============================>.] - ETA: 0s - loss: 0.7340 - auc: 0.6406 - recall: 0.5085 - precision: 0.0184WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 5s 9ms/step - loss: 0.7339 - auc: 0.6405 - recall: 0.5085 - precision: 0.0184 - val_loss: 0.7869 - val_auc: 0.6638 - val_recall: 0.5048 - val_precision: 0.0177
# Epoch 3/21
# 542/550 [============================>.] - ETA: 0s - loss: 0.6919 - auc: 0.6917 - recall: 0.5478 - precision: 0.0216
# Epoch 3: recall@5 = 0.3085
#
# Epoch 3: val_recall_at_fpr improved from -inf to 0.30851, saving model to logs/keras/model_wide_deep.keras
# 550/550 [==============================] - 5s 9ms/step - loss: 0.6909 - auc: 0.6932 - recall: 0.5500 - precision: 0.0217 - val_loss: 0.5776 - val_auc: 0.7764 - val_recall: 0.5116 - val_precision: 0.0397 - val_recall_at_fpr: 0.3085
# Epoch 4/21
# 549/550 [============================>.] - ETA: 0s - loss: 0.6119 - auc: 0.7902 - recall: 0.6813 - precision: 0.0304WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 4s 7ms/step - loss: 0.6118 - auc: 0.7902 - recall: 0.6813 - precision: 0.0303 - val_loss: 0.5594 - val_auc: 0.8127 - val_recall: 0.6668 - val_precision: 0.0348
# Epoch 5/21
# 549/550 [============================>.] - ETA: 0s - loss: 0.5644 - auc: 0.8150 - recall: 0.7166 - precision: 0.0333WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 4s 7ms/step - loss: 0.5644 - auc: 0.8150 - recall: 0.7165 - precision: 0.0333 - val_loss: 0.5118 - val_auc: 0.8194 - val_recall: 0.6726 - val_precision: 0.0381
# Epoch 6/21
# 548/550 [============================>.] - ETA: 0s - loss: 0.5472 - auc: 0.8200 - recall: 0.7189 - precision: 0.0341
# Epoch 6: recall@5 = 0.3699
#
# Epoch 6: val_recall_at_fpr improved from 0.30851 to 0.36992, saving model to logs/keras/model_wide_deep.keras
# 550/550 [==============================] - 6s 10ms/step - loss: 0.5470 - auc: 0.8201 - recall: 0.7192 - precision: 0.0341 - val_loss: 0.5155 - val_auc: 0.8202 - val_recall: 0.6992 - val_precision: 0.0367 - val_recall_at_fpr: 0.3699
# Epoch 7/21
# 544/550 [============================>.] - ETA: 0s - loss: 0.5380 - auc: 0.8226 - recall: 0.7255 - precision: 0.0344WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 4s 8ms/step - loss: 0.5376 - auc: 0.8232 - recall: 0.7261 - precision: 0.0344 - val_loss: 0.6035 - val_auc: 0.8163 - val_recall: 0.7602 - val_precision: 0.0309
# Epoch 8/21
# 546/550 [============================>.] - ETA: 0s - loss: 0.5303 - auc: 0.8252 - recall: 0.7323 - precision: 0.0351WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 4s 8ms/step - loss: 0.5309 - auc: 0.8248 - recall: 0.7310 - precision: 0.0351 - val_loss: 0.5177 - val_auc: 0.8227 - val_recall: 0.7132 - val_precision: 0.0355
# Epoch 9/21
# 549/550 [============================>.] - ETA: 0s - loss: 0.5265 - auc: 0.8255 - recall: 0.7278 - precision: 0.0349
# Epoch 9: recall@5 = 0.3743
#
# Epoch 9: val_recall_at_fpr improved from 0.36992 to 0.37427, saving model to logs/keras/model_wide_deep.keras
# 550/550 [==============================] - 5s 10ms/step - loss: 0.5264 - auc: 0.8256 - recall: 0.7279 - precision: 0.0349 - val_loss: 0.5197 - val_auc: 0.8243 - val_recall: 0.7147 - val_precision: 0.0348 - val_recall_at_fpr: 0.3743
# Epoch 10/21
# 547/550 [============================>.] - ETA: 0s - loss: 0.5215 - auc: 0.8275 - recall: 0.7323 - precision: 0.0348WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 4s 8ms/step - loss: 0.5218 - auc: 0.8274 - recall: 0.7319 - precision: 0.0348 - val_loss: 0.5039 - val_auc: 0.8261 - val_recall: 0.7074 - val_precision: 0.0361
# Epoch 11/21
# 546/550 [============================>.] - ETA: 0s - loss: 0.5188 - auc: 0.8288 - recall: 0.7303 - precision: 0.0349WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 4s 7ms/step - loss: 0.5188 - auc: 0.8288 - recall: 0.7305 - precision: 0.0349 - val_loss: 0.5310 - val_auc: 0.8266 - val_recall: 0.7355 - val_precision: 0.0340
# Epoch 12/21
# 547/550 [============================>.] - ETA: 0s - loss: 0.5173 - auc: 0.8295 - recall: 0.7386 - precision: 0.0349
# Epoch 12: recall@5 = 0.3694
#
# Epoch 12: val_recall_at_fpr did not improve from 0.37427
# 550/550 [==============================] - 5s 9ms/step - loss: 0.5171 - auc: 0.8294 - recall: 0.7384 - precision: 0.0349 - val_loss: 0.4159 - val_auc: 0.8208 - val_recall: 0.6214 - val_precision: 0.0425 - val_recall_at_fpr: 0.3694
# Epoch 13/21
# 545/550 [============================>.] - ETA: 0s - loss: 0.5172 - auc: 0.8286 - recall: 0.7357 - precision: 0.0348WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 5s 10ms/step - loss: 0.5169 - auc: 0.8287 - recall: 0.7355 - precision: 0.0348 - val_loss: 0.4425 - val_auc: 0.8195 - val_recall: 0.6557 - val_precision: 0.0390
# Epoch 14/21
# 546/550 [============================>.] - ETA: 0s - loss: 0.5165 - auc: 0.8286 - recall: 0.7413 - precision: 0.0348WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 4s 8ms/step - loss: 0.5159 - auc: 0.8287 - recall: 0.7413 - precision: 0.0348 - val_loss: 0.4100 - val_auc: 0.8220 - val_recall: 0.6267 - val_precision: 0.0427
# Epoch 15/21
# 547/550 [============================>.] - ETA: 0s - loss: 0.5137 - auc: 0.8297 - recall: 0.7362 - precision: 0.0347
# Epoch 15: recall@5 = 0.3772
#
# Epoch 15: val_recall_at_fpr improved from 0.37427 to 0.37718, saving model to logs/keras/model_wide_deep.keras
# 550/550 [==============================] - 5s 9ms/step - loss: 0.5138 - auc: 0.8297 - recall: 0.7363 - precision: 0.0348 - val_loss: 0.5469 - val_auc: 0.8266 - val_recall: 0.7476 - val_precision: 0.0324 - val_recall_at_fpr: 0.3772
# Epoch 16/21
# 544/550 [============================>.] - ETA: 0s - loss: 0.5147 - auc: 0.8292 - recall: 0.7394 - precision: 0.0348WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 4s 8ms/step - loss: 0.5144 - auc: 0.8293 - recall: 0.7400 - precision: 0.0348 - val_loss: 0.4692 - val_auc: 0.8274 - val_recall: 0.6867 - val_precision: 0.0372
# Epoch 17/21
# 545/550 [============================>.] - ETA: 0s - loss: 0.5131 - auc: 0.8296 - recall: 0.7396 - precision: 0.0345WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 4s 8ms/step - loss: 0.5132 - auc: 0.8296 - recall: 0.7397 - precision: 0.0345 - val_loss: 0.4626 - val_auc: 0.8284 - val_recall: 0.6818 - val_precision: 0.0379
# Epoch 18/21
# 549/550 [============================>.] - ETA: 0s - loss: 0.5119 - auc: 0.8310 - recall: 0.7424 - precision: 0.0347
# Epoch 18: recall@5 = 0.3868
#
# Epoch 18: val_recall_at_fpr improved from 0.37718 to 0.38685, saving model to logs/keras/model_wide_deep.keras
# 550/550 [==============================] - 5s 9ms/step - loss: 0.5118 - auc: 0.8310 - recall: 0.7424 - precision: 0.0347 - val_loss: 0.4532 - val_auc: 0.8268 - val_recall: 0.6731 - val_precision: 0.0381 - val_recall_at_fpr: 0.3868
# Epoch 19/21
# 545/550 [============================>.] - ETA: 0s - loss: 0.5125 - auc: 0.8301 - recall: 0.7408 - precision: 0.0345WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 4s 8ms/step - loss: 0.5131 - auc: 0.8299 - recall: 0.7403 - precision: 0.0345 - val_loss: 0.5103 - val_auc: 0.8277 - val_recall: 0.7321 - val_precision: 0.0344
# Epoch 20/21
# 544/550 [============================>.] - ETA: 0s - loss: 0.5107 - auc: 0.8308 - recall: 0.7411 - precision: 0.0345WARNING:tensorflow:Can save best model only with val_recall_at_fpr available, skipping.
# 550/550 [==============================] - 4s 8ms/step - loss: 0.5114 - auc: 0.8306 - recall: 0.7403 - precision: 0.0346 - val_loss: 0.6020 - val_auc: 0.8252 - val_recall: 0.7814 - val_precision: 0.0296
# Epoch 21/21
# 548/550 [============================>.] - ETA: 0s - loss: 0.5114 - auc: 0.8302 - recall: 0.7439 - precision: 0.0345
# Epoch 21: recall@5 = 0.3839
#
# Epoch 21: val_recall_at_fpr did not improve from 0.38685
# 550/550 [==============================] - 6s 11ms/step - loss: 0.5111 - auc: 0.8304 - recall: 0.7442 - precision: 0.0345 - val_loss: 0.4878 - val_auc: 0.8285 - val_recall: 0.7118 - val_precision: 0.0356 - val_recall_at_fpr: 0.3839

# %% [markdown]
# Получили слабые результаты - что-то в районе 17%. Тут мне показалось, что модель сама плохо отличает, какие признаки отнести к wide части, а какие - к deep. Поэтому я разделил данные на непрерывные и категориальные фичи. В wide часть пойдут категориальные фичи, а вот в deep - непрерывные, где сложно уловить связь с бинарной целевой переменной.

# %% [markdown]
# Update: Стало лучше, но опять же, на уровне остальных вариантов.

# %% [markdown]
# ---

# %% [markdown]
# Итого, лучшая версия - CatBoost!
